# %%
from PIL import Image as image
import torch
from torch import nn
from torchsummary import summary
import numpy as np

# %% [markdown]
# # RNN

# %%
image.open('rnn简图.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=688x634 at 0x2022522C860>

# %%
image.open('rnn计算图.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x235 at 0x202382D3080>

# %%
rnn = nn.RNN(input_size=300,hidden_size=32,num_layers=1,batch_first=True)

# %%
list(p.shape for p in rnn.parameters() if p.requires_grad)
# Out:
# [torch.Size([32, 300]),
#  torch.Size([32, 32]),
#  torch.Size([32]),
#  torch.Size([32])]

# %%
rnn2 = nn.RNN(input_size=300,hidden_size=32,num_layers=2,batch_first=True)

# %%
list(p.shape for p in rnn2.parameters() if p.requires_grad)
# Out:
# [torch.Size([32, 300]),
#  torch.Size([32, 32]),
#  torch.Size([32]),
#  torch.Size([32]),
#  torch.Size([32, 32]),
#  torch.Size([32, 32]),
#  torch.Size([32]),
#  torch.Size([32])]

# %%
image.open('rnn求导用图.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=670x272 at 0x202382D3400>

# %%
image.open('rnn前向公式.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=453x165 at 0x202382D3320>

# %%
image.open('rnn损失函数.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=202x64 at 0x202382D33C8>

# %%
image.open('rnn求导.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=754x247 at 0x202382D3780>

# %%
image.open('rnn求导2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=358x47 at 0x202382D3748>

# %%
image.open('rnn求导3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=306x93 at 0x202382D34E0>

# %% [markdown]
# # lstm

# %%
image.open('lstm简图.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=686x269 at 0x202382D3860>

# %%
image.open('遗忘门.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x222 at 0x202382D3940>

# %%
image.open('输入门.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x222 at 0x202382D39B0>

# %%
image.open('cell.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x222 at 0x202382D3BE0>

# %%
image.open('输出门.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x222 at 0x202382D3B00>

# %%
image.open('lstm公式.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=383x279 at 0x202382D3D30>

# %%
lstm = nn.LSTM(input_size=300,hidden_size=32)

# %%
list(p.shape for p in lstm.parameters() if p.requires_grad)
# Out:
# [torch.Size([128, 300]),
#  torch.Size([128, 32]),
#  torch.Size([128]),
#  torch.Size([128])]

# %% [markdown]
# # GRU

# %%
image.open('gru.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=580x191 at 0x1A7C002BB70>

# %%
image.open('重置门更新门理解.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=802x227 at 0x1A7C00F2E48>

# %%
gru = nn.GRU(input_size=300,hidden_size=32)

# %%
list(p.shape for p in gru.parameters() if p.requires_grad)
# Out:
# [torch.Size([96, 300]),
#  torch.Size([96, 32]),
#  torch.Size([96]),
#  torch.Size([96])]

# %% [markdown]
# # RNN结构

# %%
image.open('NvsN.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x311 at 0x1A7C0103470>

# %%
image.open('1vsN.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=566x371 at 0x1A7C01037F0>

# %%
image.open('1vsN2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=528x371 at 0x1A7C01038D0>

# %%
image.open('Nvs1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=516x290 at 0x1A7C0103978>

# %%
image.open('MvsN.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=787x379 at 0x1A7C0103A20>

# %%
image.open('MvsN2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=817x418 at 0x1A7C0103AC8>
